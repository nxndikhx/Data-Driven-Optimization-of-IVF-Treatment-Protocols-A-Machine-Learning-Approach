# %%
import pandas as pd
import xlrd
df = pd.read_excel("Clinical parameters Dataset.xlsx")
df
# Out:
#        №  Age  IVF/ICSI cycle  FSH, IU/L  LH, IU/L  AMH, ng/mL  \
# 0      1   35               1       7.30      2.42        1.19
# 1      2   33               1       8.80      6.90        5.90
# 2      3   38               1       9.40      3.70        3.04
# 3      4   30               1       5.76      5.55        1.86
# 4      5   34               1       6.35      8.80        2.25
# ..   ...  ...             ...        ...       ...         ...
# 139  140   33               1       6.90     11.10        3.80
# 140  141   34               2       7.91      4.21        2.94
# 141  142   34               1       5.67      3.98        1.32
# 142  143   34               1       8.18     11.20       10.02
# 143  144   34               2       6.12     10.10        9.51
#
#      Progesterone, nmol/L  Follicles obtained  LH/FSH ratio FSHB c.-211 G>T  \
# 0                    8.20                  10      0.331507              TT
# ...
